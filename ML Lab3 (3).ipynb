# %%
import pandas as pd
import numpy as np
df=pd.read_excel('embeddingdata.xlsx')
df
# Out:
#       embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0    0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1   -0.007535 -0.039844  0.030167  0.031224  0.004742  0.028289 -0.068723
# 2    0.022408 -0.030840  0.032328  0.046965  0.007798  0.025860 -0.065093
# 3    0.019677 -0.034055  0.012662  0.070387 -0.011170  0.017842 -0.050945
# 4    0.017678 -0.030323  0.012829  0.065267 -0.025161  0.011964 -0.050590
# ..        ...       ...       ...       ...       ...       ...       ...
# 895  0.019743 -0.071799  0.022546  0.049042 -0.005767 -0.016275 -0.037731
# 896  0.000186 -0.027604  0.010623  0.038237 -0.026675  0.020215 -0.040816
# 897  0.018066 -0.032152  0.039794  0.047608  0.003898  0.024092 -0.056508
# 898 -0.003492 -0.022739  0.021777  0.044054 -0.005621  0.013863 -0.079196
# 899  0.013689 -0.037855  0.039763  0.035750  0.004115  0.005637 -0.050556
#
#       embed_7   embed_8   embed_9  ...  embed_759  embed_760  embed_761  \
# ...

# %%
class_0_df = df[df['Label'] == 0]
class_1_df = df[df['Label'] == 1]
class_2_df = df[df['Label'] == 2]
class_3_df = df[df['Label'] == 3]
class_4_df = df[df['Label'] == 4]
class_5_df = df[df['Label'] == 5]
print("class0 data:")
class_0_df
# Out:
# class0 data:
#       embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0    0.009625 -0.029216  0.027109  0.023631 -0.004972  0.031757 -0.045125
# 1   -0.007535 -0.039844  0.030167  0.031224  0.004742  0.028289 -0.068723
# 2    0.022408 -0.030840  0.032328  0.046965  0.007798  0.025860 -0.065093
# 3    0.019677 -0.034055  0.012662  0.070387 -0.011170  0.017842 -0.050945
# 4    0.017678 -0.030323  0.012829  0.065267 -0.025161  0.011964 -0.050590
# ..        ...       ...       ...       ...       ...       ...       ...
# 885  0.033793 -0.041482  0.018117  0.040605 -0.003167  0.012903 -0.064144
# 886 -0.017361 -0.027632  0.046716  0.051369  0.013664  0.026783 -0.044779
# 887  0.014825 -0.009143  0.027927  0.041078  0.008816  0.026527 -0.081058
# 892 -0.023572 -0.033980  0.022470  0.066130  0.002915  0.029243 -0.061348
# 896  0.000186 -0.027604  0.010623  0.038237 -0.026675  0.020215 -0.040816
#
# ...

# %%
print("class1 data:")
class_1_df
# Out:
# class1 data:
#       embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 5    0.020490 -0.033388  0.041006  0.048247  0.002952  0.010657 -0.055723
# 8    0.016423 -0.028484  0.024103  0.048108  0.007193  0.014493 -0.067380
# 11   0.003003 -0.034048  0.028498  0.042816  0.007582  0.013160 -0.068387
# 12   0.014169 -0.019783  0.032008  0.046424  0.008417  0.022123 -0.060364
# 20   0.015770 -0.039677  0.022405  0.045627  0.002147  0.019411 -0.073581
# ..        ...       ...       ...       ...       ...       ...       ...
# 871  0.023411 -0.024035  0.017527  0.034507  0.015159  0.024006 -0.061574
# 873  0.020432 -0.025563  0.022175  0.030046  0.003004  0.014688 -0.075619
# 877  0.012343 -0.011543  0.036581  0.041522 -0.006446 -0.009757 -0.055867
# 888 -0.006383 -0.030809  0.031943  0.023811 -0.006981  0.026279 -0.058225
# 889  0.002020 -0.022297  0.027101  0.048817  0.001564 -0.009862 -0.052936
#
# ...

# %%
class_0_arr = class_0_df.drop(columns=['Label']).values
class_1_arr = class_1_df.drop(columns=['Label']).values

# %%
#finding centroid of classes with label value 0 and 1
centroid_class_0 = np.mean(class_0_arr, axis=0)
centroid_class_1 = np.mean(class_1_arr, axis=0)
print("Centroid of class0 is:")
print(centroid_class_0)
print("Centroid of class1 is:")
print(centroid_class_1)
# Out:
# Centroid of class0 is:
# [ 6.93396530e-03 -2.92363779e-02  2.71120351e-02  4.24414948e-02
#  -2.27521681e-03  1.40538988e-02 -5.98755591e-02  3.79871104e-02
#   3.28349247e-02 -2.48905972e-02  3.76273041e-02 -4.44744284e-02
#   7.80751580e-02 -2.10547694e-03  7.06716521e-02  1.08736439e-02
#  -8.57578171e-03 -1.27622606e-02  2.78747200e-02  3.52300280e-02
#   1.41228108e-02 -4.31123486e-02 -3.50587808e-02  1.63326926e-02
#  -4.03043819e-02  2.43452528e-02  8.07588033e-03 -2.39142361e-02
#  -1.74494194e-03  3.03599488e-02  5.20313514e-02 -5.20257869e-03
#  -1.19760621e-02  5.45701038e-02 -4.18126885e-02  2.56344932e-02
#  -3.57541222e-02 -6.19825985e-02 -3.88748499e-02  1.19321084e-02
#   3.88917425e-03 -5.16110905e-02 -2.88013025e-02  4.30589334e-02
#  -4.93740651e-02 -1.79521214e-02  1.51590659e-02  5.52739135e-02
#  -2.48371628e-02 -5.71472348e-02 -6.01828730e-02 -6.41265983e-02
#  -3.87850897e-02 -2.10232881e-02 -4.41709021e-02  6.98709533e-04
# ...

# %%
#finding standard deviation of classes with label value 0 and 1
sd_class_0 = np.std(class_0_arr, axis=0)
sd_class_1 = np.std(class_1_arr, axis=0)
print("Standard deviation of class0 is:")
print(sd_class_0)
print("Standard deviation of class1 is:")
print(sd_class_1)
# Out:
# Standard deviation of class0 is:
# [0.01293223 0.01390183 0.0121483  0.01198753 0.01227932 0.01115059
#  0.01007727 0.0099809  0.01148856 0.009348   0.01108594 0.01135964
#  0.0106429  0.01045705 0.0106025  0.01198376 0.01016966 0.0116819
#  0.01161697 0.01025452 0.01158547 0.01204993 0.01263933 0.01292106
#  0.01311    0.01119263 0.01130136 0.0155473  0.01015887 0.01194398
#  0.01200369 0.0111692  0.01413776 0.01370974 0.01037035 0.01071712
#  0.01238072 0.016361   0.01281465 0.00922191 0.01271443 0.01211584
#  0.01037309 0.01078151 0.01195847 0.01158379 0.00915844 0.01400002
#  0.01062667 0.00988708 0.01348598 0.01415621 0.01089404 0.01284735
#  0.0114948  0.01265388 0.01207014 0.01032    0.00996525 0.01391452
#  0.01237294 0.01276925 0.01213285 0.01440823 0.01101585 0.01231714
#  0.01118211 0.01229298 0.01276286 0.01441778 0.01295595 0.01045303
#  0.01257633 0.01303287 0.01303321 0.01085532 0.01217334 0.01289728
#  0.01337059 0.01215869 0.01443603 0.01126317 0.01416643 0.01191089
# ...

# %%
from scipy.spatial.distance import euclidean

# %%
#calculating interclass distance
euclidean_distance = euclidean(centroid_class_0, centroid_class_1)
print("Distance between centroids i.e interclass distance is:")
print(euclidean_distance)
# Out:
# Distance between centroids i.e interclass distance is:
# 0.14063147845274573

# %%
#calculating intradistance of class_0
intradistance_class_0 = np.mean(np.linalg.norm(class_0_arr - centroid_class_0, axis=1))

# %%
print("Intradistance of class0 is:")
print(intradistance_class_0)
# Out:
# Intradistance of class0 is:
# 0.32439760239265913

# %%
#calculating intradistance of class_1
intradistance_class_1 = np.mean(np.linalg.norm(class_1_arr - centroid_class_1, axis=1))

# %%
print("Intradistance of class1 is:")
print(intradistance_class_1)
# Out:
# Intradistance of class1 is:
# 0.29836748350682446

# %%
import numpy as np
import matplotlib.pyplot as plt
num_bins = 5
columnn=df['embed_4']
hist_values, bin_edges = np.histogram(df, bins=num_bins)
plt.hist(columnn, bins=bin_edges, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Your Dataset')
plt.show()

# %%
mean=df['embed_4'].mean()
mean
# Out:
# 0.0007589936186193174

# %%
variance = np.var(columnn)
variance
# Out:
# 0.00016400823094694448

# %%
variance=df['embed_4'].var()
variance
# Out:
# 0.000164190665019188

# %%
import pandas as pd
vector1 = df.loc[0, ["embed_1", "embed_2"]].values
vector2 = df.loc[1, ["embed_1", "embed_2"]].values
print("Feature Vector 1:")
print(vector1)
print("\nFeature Vector 2:")
print(vector2)
# Out:
# Feature Vector 1:
# [-0.02921622  0.02710896]
#
# Feature Vector 2:
# [-0.03984416  0.03016686]

# %%
def minkowski_distance(x, y, r):
    return np.sum(np.abs(x - y) ** r) ** (1 / r)
values_r = range(1, 11)
distances = [minkowski_distance(vector1, vector2, r) for r in r_values]
print(distances)
plt.figure(figsize=(10, 7))
plt.plot(r_values, distances, marker='o', linestyle='-')
plt.title("Minkowski Distance vs Values of r")
plt.xlabel("r")
plt.ylabel("Minkowski Distance")
plt.grid(True)
plt.show()
# Out:
# [0.013685844838619229, 0.011059107872861962, 0.010711659856116785, 0.010646100973271668, 0.010632126491069226, 0.010628943156890528, 0.010628186260396608, 0.010628000829711213, 0.010627954392550628, 0.010627942566857852]

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=['Labels'])
y = df['Labels']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14504\2594520395.py in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X = df.drop(columns=['Labels'])
#       3 y = df['Labels']
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)
#
# ~\Documents\anaconda new\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Documents\anaconda new\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
# ...
